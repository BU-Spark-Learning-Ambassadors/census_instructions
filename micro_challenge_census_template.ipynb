# %% [markdown]
# # Visualizing the Census Microchallenge!
#
# This challenge consists of 4 parts and one extra challenge. Follow the steps outlined to request data from the official Census API, create a bar chart, and create a pie chart.

# %% [markdown]
# ### Part A: Install and Import Libraries
# We will be using pandas for data manipulation, matplotlib for data visualization, and requests to fetch data from the Census API.

# %%
# add your code here(only need 3 libraries for this challenge, you are more than welcome to add more :)
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %% [markdown]
# ### Part B: Fetch Census Data, fetch a simple dataset from the Census API. for example you could do: population data by race for Massachusetts.

# %%
# Set MA specific Variables
year = '2020'
dsource = 'dec'
dname = 'pl'
state = '25'  # Massachusetts

# Specify Data Columns
cols = 'NAME,P2_005N,P2_006N,P2_007N,P2_008N,P2_009N'  # White, Black, American Indian, Asian, Native Hawaiian

# Call the Census API
census_url = f"https://api.census.gov/data/{year}/{dsource}/{dname}?get={cols}&for=state:{state}"

# TODO: use the requests library to call the API!!!

# TODO: add some error handling to make sure the response was successful
# Out:
# Data fetched successfully!

# %% [markdown]
# ### Part C: Convert Data to DataFrame and Clean

# %%
# Convert to DataFrame

# Convert numeric columns to integers

# Rename columns for better understanding

# Display the cleaned data
# Out:
#             NAME    White   Black  American Indian   Asian  Native Hawaiian  \
# 0  Massachusetts  4748897  457055             9387  504900             1607
#
#   state
# 0    25

# %% [markdown]
# ### Part D: Create a Bar Chart, (You are more than welcome to try others visualization Methods)

# %%
# Set the aesthetic style of the plots (optional)

# Create Bar Chart

# Set Titles and Labels


# Show Plot
# Out:
# <ipython-input-5-0d6b9c646bea>:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %% [markdown]
# ### Extra: try to make a pie chart! 🍰

# %%
# use column names will be used as labels


# use the first row of data (you can change this as needed)

# Create a pie chart

# Add a title

# Display the chart

# %% [markdown]
# ### Congratulations, nice job working on this microchallenge!
